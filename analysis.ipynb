# %%
import pandas as pd
from pathlib import Path

data_dir = Path("/Users/muhammadmuhdhar/Downloads/repo/nb-smith/tests/data/Credit Data")

# CSV files
Age_Bracket_Distribution = pd.read_csv(data_dir / "Age_Bracket_Distribution.csv")
Age_Income_Risk_Matrix = pd.read_csv(data_dir / "Age_Income_Risk_Matrix.csv")
Age_Risk_Summary = pd.read_csv(data_dir / "Age_Risk_Summary.csv")
Broken_Contract_Analysis = pd.read_csv(data_dir / "Broken_Contract_Analysis.csv")
Credit_Data___01_01_2025 = pd.read_csv(data_dir / "Credit Data - 01-01-2025.csv")
Credit_Data___30_03_2025 = pd.read_csv(data_dir / "Credit Data - 30-03-2025.csv")
Credit_Data___30_06_2025 = pd.read_csv(data_dir / "Credit Data - 30-06-2025.csv")
Credit_Data___30_09_2025 = pd.read_csv(data_dir / "Credit Data - 30-09-2025.csv")
Credit_Data___30_12_2025 = pd.read_csv(data_dir / "Credit Data - 30-12-2025.csv")
DPD_vs_NPS = pd.read_csv(data_dir / "DPD_vs_NPS.csv")
Income_Bracket_Distribution = pd.read_csv(data_dir / "Income_Bracket_Distribution.csv")
Monthly_Cure_Rates = pd.read_csv(data_dir / "Monthly_Cure_Rates.csv")
Portfolio_Summary = pd.read_csv(data_dir / "Portfolio_Summary.csv")
Vintage_Analysis_MOB12 = pd.read_csv(data_dir / "Vintage_Analysis_MOB12.csv")

# Excel files
Credit_Data_Definitions = pd.read_excel(data_dir / "Credit Data Definitions.xlsx", sheet_name="Credit Data Definitions")
NPS_Data = pd.read_excel(data_dir / "NPS Data.xlsx", sheet_name="Sheet1")
Sales_and_Customer_Data_Sales_Details = pd.read_excel(data_dir / "Sales and Customer Data.xlsx", sheet_name="Sales Details")
Sales_and_Customer_Data_Gender = pd.read_excel(data_dir / "Sales and Customer Data.xlsx", sheet_name="Gender")
Sales_and_Customer_Data_DOB = pd.read_excel(data_dir / "Sales and Customer Data.xlsx", sheet_name="DOB")
Sales_and_Customer_Data_Income_Level = pd.read_excel(data_dir / "Sales and Customer Data.xlsx", sheet_name="Income Level")

# %%
# Profile: Age_Bracket_Distribution
print("\n" + "="*60)
print("DataFrame: Age_Bracket_Distribution")
print("="*60)

# Shape
print(f"\nShape: {Age_Bracket_Distribution.shape[0]:,} rows, {Age_Bracket_Distribution.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Age_Bracket_Distribution.info()

# Head
print("\n--- Head (5 rows) ---")
display(Age_Bracket_Distribution.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Age_Bracket_Distribution.tail())

# Describe
print("\n--- Describe ---")
display(Age_Bracket_Distribution.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Age_Bracket_Distribution.isnull().sum()
null_pct = (Age_Bracket_Distribution.isnull().sum() / len(Age_Bracket_Distribution)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Age_Bracket_Distribution.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Age_Bracket_Distribution
# ...
#
# Shape: 5 rows, 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age_brackets  5 non-null      object
#  1   proportion    5 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 212.0+ bytes
#
# --- Head (5 rows) ---
#   age_brackets  proportion
# 0        26-35   53.857168
# 1        18-25   21.693216
# 2        36-45   17.791301
# 3        46-55    5.271165
# 4          55+    1.387149
# --- Tail (5 rows) ---
#   age_brackets  proportion
# 0        26-35   53.857168
# 1        18-25   21.693216
# 2        36-45   17.791301
# 3        46-55    5.271165
# 4          55+    1.387149
# --- Describe ---
#        age_brackets  proportion
# count             5    5.000000
# unique            5         NaN
# top           26-35         NaN
# ...

# %%
# Profile: Age_Income_Risk_Matrix
print("\n" + "="*60)
print("DataFrame: Age_Income_Risk_Matrix")
print("="*60)

# Shape
print(f"\nShape: {Age_Income_Risk_Matrix.shape[0]:,} rows, {Age_Income_Risk_Matrix.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Age_Income_Risk_Matrix.info()

# Head
print("\n--- Head (5 rows) ---")
display(Age_Income_Risk_Matrix.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Age_Income_Risk_Matrix.tail())

# Describe
print("\n--- Describe ---")
display(Age_Income_Risk_Matrix.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Age_Income_Risk_Matrix.isnull().sum()
null_pct = (Age_Income_Risk_Matrix.isnull().sum() / len(Age_Income_Risk_Matrix)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Age_Income_Risk_Matrix.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Age_Income_Risk_Matrix
# ...
#
# Shape: 5 rows, 9 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age_brackets  5 non-null      object
#  1   Below 5k      3 non-null      float64
#  2   5k-10k        5 non-null      float64
#  3   10k-20k       5 non-null      float64
#  4   20k-30k       5 non-null      float64
#  5   30k-50k       5 non-null      float64
#  6   50k-100k      5 non-null      float64
#  7   100k-150k     5 non-null      float64
#  8   150k+         5 non-null      float64
# dtypes: float64(8), object(1)
# memory usage: 492.0+ bytes
#
# --- Head (5 rows) ---
#   age_brackets   Below 5k     5k-10k    10k-20k    20k-30k    30k-50k  \
# 0        18-25   0.000000  39.130435  39.200000  41.395349  35.564854
# 1        26-35  35.714286  34.090909  36.885246  34.634146  37.248322
# ...

# %%
# Profile: Age_Risk_Summary
print("\n" + "="*60)
print("DataFrame: Age_Risk_Summary")
print("="*60)

# Shape
print(f"\nShape: {Age_Risk_Summary.shape[0]:,} rows, {Age_Risk_Summary.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Age_Risk_Summary.info()

# Head
print("\n--- Head (5 rows) ---")
display(Age_Risk_Summary.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Age_Risk_Summary.tail())

# Describe
print("\n--- Describe ---")
display(Age_Risk_Summary.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Age_Risk_Summary.isnull().sum()
null_pct = (Age_Risk_Summary.isnull().sum() / len(Age_Risk_Summary)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Age_Risk_Summary.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Age_Risk_Summary
# ...
#
# Shape: 5 rows, 8 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age_brackets          5 non-null      object
#  1   is_par_30             5 non-null      float64
#  2   is_par_90             5 non-null      float64
#  3   WEEKLY_RATE           5 non-null      float64
#  4   LOAN_ID               5 non-null      int64
#  5   Share_of_Total_PAR30  5 non-null      float64
#  6   is_par_90%            5 non-null      float64
#  7   share_of_par_30%      5 non-null      float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 452.0+ bytes
#
# --- Head (5 rows) ---
#   age_brackets  is_par_30  is_par_90  WEEKLY_RATE  LOAN_ID  \
# 0        18-25   0.329620   0.235561  1125.028878     2424
# 1        26-35   0.295613   0.212529  1248.087087     6018
# ...

# %%
# Profile: Broken_Contract_Analysis
print("\n" + "="*60)
print("DataFrame: Broken_Contract_Analysis")
print("="*60)

# Shape
print(f"\nShape: {Broken_Contract_Analysis.shape[0]:,} rows, {Broken_Contract_Analysis.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Broken_Contract_Analysis.info()

# Head
print("\n--- Head (5 rows) ---")
display(Broken_Contract_Analysis.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Broken_Contract_Analysis.tail())

# Describe
print("\n--- Describe ---")
display(Broken_Contract_Analysis.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Broken_Contract_Analysis.isnull().sum()
null_pct = (Broken_Contract_Analysis.isnull().sum() / len(Broken_Contract_Analysis)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Broken_Contract_Analysis.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Broken_Contract_Analysis
# ...
#
# Shape: 2 rows, 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Status     2 non-null      object
#  1   NPS_Score  2 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 164.0+ bytes
#
# --- Head (5 rows) ---
#                         Status  NPS_Score
# 0          On-Time (No Issues)   7.479687
# 1  On-Time (System Lock Error)   6.225191
# --- Tail (5 rows) ---
#                         Status  NPS_Score
# 0          On-Time (No Issues)   7.479687
# 1  On-Time (System Lock Error)   6.225191
# --- Describe ---
#                      Status  NPS_Score
# count                     2   2.000000
# unique                    2        NaN
# top     On-Time (No Issues)        NaN
# freq                      1        NaN
# mean                    NaN   6.852439
# ...

# %%
# Profile: Credit_Data___01_01_2025
print("\n" + "="*60)
print("DataFrame: Credit_Data___01_01_2025")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data___01_01_2025.shape[0]:,} rows, {Credit_Data___01_01_2025.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data___01_01_2025.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data___01_01_2025.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data___01_01_2025.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data___01_01_2025.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data___01_01_2025.isnull().sum()
null_pct = (Credit_Data___01_01_2025.isnull().sum() / len(Credit_Data___01_01_2025)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data___01_01_2025.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data___01_01_2025
# ...
#
# Shape: 8,935 rows, 33 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8935 entries, 0 to 8934
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOAN_ID                          8935 non-null   object
#  1   DATE                             8935 non-null   object
#  2   CUSTOMER_AGE                     8935 non-null   int64
#  3   TOTAL_PAID                       8935 non-null   int64
#  4   TOTAL_DUE_TODAY                  8930 non-null   float64
#  5   BALANCE                          8934 non-null   float64
#  6   DAYS_PAST_DUE                    8935 non-null   int64
#  7   CLOSING_BALANCE                  8934 non-null   float64
#  8   ADVANCE                          8935 non-null   int64
#  9   BALANCE_DUE_TO_DATE              8930 non-null   float64
# ...

# %%
# Profile: Credit_Data___30_03_2025
print("\n" + "="*60)
print("DataFrame: Credit_Data___30_03_2025")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data___30_03_2025.shape[0]:,} rows, {Credit_Data___30_03_2025.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data___30_03_2025.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data___30_03_2025.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data___30_03_2025.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data___30_03_2025.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data___30_03_2025.isnull().sum()
null_pct = (Credit_Data___30_03_2025.isnull().sum() / len(Credit_Data___30_03_2025)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data___30_03_2025.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data___30_03_2025
# ...
#
# Shape: 11,024 rows, 33 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11024 entries, 0 to 11023
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOAN_ID                          11024 non-null  object
#  1   DATE                             11024 non-null  object
#  2   CUSTOMER_AGE                     11024 non-null  int64
#  3   TOTAL_PAID                       11024 non-null  int64
#  4   TOTAL_DUE_TODAY                  11019 non-null  float64
#  5   BALANCE                          11023 non-null  float64
#  6   DAYS_PAST_DUE                    11024 non-null  int64
#  7   CLOSING_BALANCE                  11023 non-null  float64
#  8   ADVANCE                          11024 non-null  int64
#  9   BALANCE_DUE_TO_DATE              11019 non-null  float64
# ...

# %%
# Profile: Credit_Data___30_06_2025
print("\n" + "="*60)
print("DataFrame: Credit_Data___30_06_2025")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data___30_06_2025.shape[0]:,} rows, {Credit_Data___30_06_2025.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data___30_06_2025.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data___30_06_2025.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data___30_06_2025.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data___30_06_2025.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data___30_06_2025.isnull().sum()
null_pct = (Credit_Data___30_06_2025.isnull().sum() / len(Credit_Data___30_06_2025)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data___30_06_2025.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data___30_06_2025
# ...
#
# Shape: 13,891 rows, 34 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13891 entries, 0 to 13890
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOAN_ID                          13891 non-null  object
#  1   DATE                             13891 non-null  object
#  2   CUSTOMER_AGE                     13891 non-null  int64
#  3   TOTAL_PAID                       13891 non-null  int64
#  4   TOTAL_DUE_TODAY                  13885 non-null  float64
#  5   BALANCE                          13889 non-null  float64
#  6   DAYS_PAST_DUE                    13891 non-null  int64
#  7   CLOSING_BALANCE                  13889 non-null  float64
#  8   ADVANCE                          13891 non-null  float64
#  9   BALANCE_DUE_TO_DATE              13885 non-null  float64
# ...

# %%
# Profile: Credit_Data___30_09_2025
print("\n" + "="*60)
print("DataFrame: Credit_Data___30_09_2025")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data___30_09_2025.shape[0]:,} rows, {Credit_Data___30_09_2025.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data___30_09_2025.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data___30_09_2025.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data___30_09_2025.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data___30_09_2025.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data___30_09_2025.isnull().sum()
null_pct = (Credit_Data___30_09_2025.isnull().sum() / len(Credit_Data___30_09_2025)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data___30_09_2025.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data___30_09_2025
# ...
#
# Shape: 16,864 rows, 34 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16864 entries, 0 to 16863
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOAN_ID                          16864 non-null  object
#  1   DATE                             16864 non-null  object
#  2   CUSTOMER_AGE                     16864 non-null  int64
#  3   TOTAL_PAID                       16864 non-null  int64
#  4   TOTAL_DUE_TODAY                  16858 non-null  float64
#  5   BALANCE                          16862 non-null  float64
#  6   DAYS_PAST_DUE                    16864 non-null  int64
#  7   CLOSING_BALANCE                  16862 non-null  float64
#  8   ADVANCE                          16864 non-null  float64
#  9   BALANCE_DUE_TO_DATE              16858 non-null  float64
# ...

# %%
# Profile: Credit_Data___30_12_2025
print("\n" + "="*60)
print("DataFrame: Credit_Data___30_12_2025")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data___30_12_2025.shape[0]:,} rows, {Credit_Data___30_12_2025.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data___30_12_2025.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data___30_12_2025.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data___30_12_2025.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data___30_12_2025.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data___30_12_2025.isnull().sum()
null_pct = (Credit_Data___30_12_2025.isnull().sum() / len(Credit_Data___30_12_2025)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data___30_12_2025.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data___30_12_2025
# ...
#
# Shape: 20,742 rows, 34 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20742 entries, 0 to 20741
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LOAN_ID                          20742 non-null  object
#  1   DATE                             20742 non-null  object
#  2   CUSTOMER_AGE                     20742 non-null  int64
#  3   TOTAL_PAID                       20742 non-null  int64
#  4   TOTAL_DUE_TODAY                  20736 non-null  float64
#  5   BALANCE                          20740 non-null  float64
#  6   DAYS_PAST_DUE                    20742 non-null  int64
#  7   CLOSING_BALANCE                  20740 non-null  float64
#  8   ADVANCE                          20742 non-null  float64
#  9   BALANCE_DUE_TO_DATE              20736 non-null  float64
# ...

# %%
# Profile: DPD_vs_NPS
print("\n" + "="*60)
print("DataFrame: DPD_vs_NPS")
print("="*60)

# Shape
print(f"\nShape: {DPD_vs_NPS.shape[0]:,} rows, {DPD_vs_NPS.shape[1]:,} columns")

# Info
print("\n--- Info ---")
DPD_vs_NPS.info()

# Head
print("\n--- Head (5 rows) ---")
display(DPD_vs_NPS.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(DPD_vs_NPS.tail())

# Describe
print("\n--- Describe ---")
display(DPD_vs_NPS.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = DPD_vs_NPS.isnull().sum()
null_pct = (DPD_vs_NPS.isnull().sum() / len(DPD_vs_NPS)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = DPD_vs_NPS.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: DPD_vs_NPS
# ...
#
# Shape: 90 rows, 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DAYS_PAST_DUE  90 non-null     int64
#  1   NPS_Score      90 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.5 KB
#
# --- Head (5 rows) ---
#    DAYS_PAST_DUE  NPS_Score
# 0              0   7.114835
# 1              1   7.059406
# 2              2   7.000000
# 3              3   6.794872
# 4              4   6.675676
# --- Tail (5 rows) ---
#     DAYS_PAST_DUE  NPS_Score
# 85             85   8.000000
# 86             87   9.666667
# 87             88   9.500000
# 88             89   7.500000
# 89             90   6.800000
# --- Describe ---
#        DAYS_PAST_DUE  NPS_Score
# count      90.000000  90.000000
# mean       44.544444   7.068158
# std        26.199391   1.644792
# ...

# %%
# Profile: Income_Bracket_Distribution
print("\n" + "="*60)
print("DataFrame: Income_Bracket_Distribution")
print("="*60)

# Shape
print(f"\nShape: {Income_Bracket_Distribution.shape[0]:,} rows, {Income_Bracket_Distribution.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Income_Bracket_Distribution.info()

# Head
print("\n--- Head (5 rows) ---")
display(Income_Bracket_Distribution.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Income_Bracket_Distribution.tail())

# Describe
print("\n--- Describe ---")
display(Income_Bracket_Distribution.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Income_Bracket_Distribution.isnull().sum()
null_pct = (Income_Bracket_Distribution.isnull().sum() / len(Income_Bracket_Distribution)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Income_Bracket_Distribution.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Income_Bracket_Distribution
# ...
#
# Shape: 8 rows, 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   income_bracket  8 non-null      object
#  1   proportion      8 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 260.0+ bytes
#
# --- Head (5 rows) ---
#   income_bracket  proportion
# 0          150k+   42.143463
# 1       50k-100k   22.650580
# 2      100k-150k   14.553681
# 3        30k-50k   12.065228
# 4        20k-30k    4.778961
# --- Tail (5 rows) ---
#   income_bracket  proportion
# 3        30k-50k   12.065228
# 4        20k-30k    4.778961
# 5        10k-20k    2.780658
# 6         5k-10k    0.735225
# 7       Below 5k    0.292205
# --- Describe ---
#        income_bracket  proportion
# count               8    8.000000
# unique              8         NaN
# ...

# %%
# Profile: Monthly_Cure_Rates
print("\n" + "="*60)
print("DataFrame: Monthly_Cure_Rates")
print("="*60)

# Shape
print(f"\nShape: {Monthly_Cure_Rates.shape[0]:,} rows, {Monthly_Cure_Rates.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Monthly_Cure_Rates.info()

# Head
print("\n--- Head (5 rows) ---")
display(Monthly_Cure_Rates.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Monthly_Cure_Rates.tail())

# Describe
print("\n--- Describe ---")
display(Monthly_Cure_Rates.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Monthly_Cure_Rates.isnull().sum()
null_pct = (Monthly_Cure_Rates.isnull().sum() / len(Monthly_Cure_Rates)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Monthly_Cure_Rates.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Monthly_Cure_Rates
# ...
#
# Shape: 5 rows, 3 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Month            5 non-null      object
#  1   Cure_Rate        5 non-null      float64
#  2   Delinquent_Pool  5 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 252.0+ bytes
#
# --- Head (5 rows) ---
#                  Month  Cure_Rate  Delinquent_Pool
# 0                  Mar   0.005573             3768
# 1                  Jun   0.014174             4868
# 2                  Sep   0.016901             6035
# 3                  Dec   0.019150             7415
# 4  Jan-Dec (Full Year)   0.000000             3768
# --- Tail (5 rows) ---
#                  Month  Cure_Rate  Delinquent_Pool
# 0                  Mar   0.005573             3768
# ...

# %%
# Profile: Portfolio_Summary
print("\n" + "="*60)
print("DataFrame: Portfolio_Summary")
print("="*60)

# Shape
print(f"\nShape: {Portfolio_Summary.shape[0]:,} rows, {Portfolio_Summary.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Portfolio_Summary.info()

# Head
print("\n--- Head (5 rows) ---")
display(Portfolio_Summary.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Portfolio_Summary.tail())

# Describe
print("\n--- Describe ---")
display(Portfolio_Summary.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Portfolio_Summary.isnull().sum()
null_pct = (Portfolio_Summary.isnull().sum() / len(Portfolio_Summary)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Portfolio_Summary.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Portfolio_Summary
# ...
#
# Shape: 5 rows, 12 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    5 non-null      object
#  1   Unique Loans             5 non-null      int64
#  2   Total_Outstanding_Value  5 non-null      float64
#  3   Total_Arrears            5 non-null      float64
#  4   Volume_Growth_%          4 non-null      float64
#  5   Value_Growth_%           4 non-null      float64
#  6   Arrears_growth_%         4 non-null      float64
#  7   Avg_Loan_Balance         5 non-null      float64
#  8   Arrears_Ratio_%          5 non-null      float64
#  9   Arrears_ratio_growth_%   4 non-null      float64
#  10  Unique Loans_indexed     5 non-null      float64
#  11  Total_Arrears_indexed    5 non-null      float64
# ...

# %%
# Profile: Vintage_Analysis_MOB12
print("\n" + "="*60)
print("DataFrame: Vintage_Analysis_MOB12")
print("="*60)

# Shape
print(f"\nShape: {Vintage_Analysis_MOB12.shape[0]:,} rows, {Vintage_Analysis_MOB12.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Vintage_Analysis_MOB12.info()

# Head
print("\n--- Head (5 rows) ---")
display(Vintage_Analysis_MOB12.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Vintage_Analysis_MOB12.tail())

# Describe
print("\n--- Describe ---")
display(Vintage_Analysis_MOB12.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Vintage_Analysis_MOB12.isnull().sum()
null_pct = (Vintage_Analysis_MOB12.isnull().sum() / len(Vintage_Analysis_MOB12)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Vintage_Analysis_MOB12.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Vintage_Analysis_MOB12
# ...
#
# Shape: 10 rows, 3 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Vintage  10 non-null     object
#  1   PAR30    10 non-null     float64
#  2   PAR90    10 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 372.0+ bytes
#
# --- Head (5 rows) ---
#    Vintage  PAR30  PAR90
# 0  2024-01  40.74  39.51
# 1  2024-02  44.09  38.18
# 2  2024-03  55.38  52.69
# 3  2024-04  54.21  51.84
# 4  2024-06  50.66  47.60
# --- Tail (5 rows) ---
#    Vintage  PAR30  PAR90
# 5  2024-07  49.92  47.60
# 6  2024-09  51.93  50.83
# 7  2024-10  52.85  50.37
# 8  2024-12  47.10  44.20
# 9  2025-01  48.95  43.72
# --- Describe ---
#         Vintage      PAR30      PAR90
# count        10  10.000000  10.000000
# unique       10        NaN        NaN
# top     2024-01        NaN        NaN
# ...

# %%
# Profile: Credit_Data_Definitions
print("\n" + "="*60)
print("DataFrame: Credit_Data_Definitions")
print("="*60)

# Shape
print(f"\nShape: {Credit_Data_Definitions.shape[0]:,} rows, {Credit_Data_Definitions.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Credit_Data_Definitions.info()

# Head
print("\n--- Head (5 rows) ---")
display(Credit_Data_Definitions.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Credit_Data_Definitions.tail())

# Describe
print("\n--- Describe ---")
display(Credit_Data_Definitions.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Credit_Data_Definitions.isnull().sum()
null_pct = (Credit_Data_Definitions.isnull().sum() / len(Credit_Data_Definitions)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Credit_Data_Definitions.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Credit_Data_Definitions
# ...
#
# Shape: 33 rows, 2 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column Name  33 non-null     object
#  1   Definition   33 non-null     object
# dtypes: object(2)
# memory usage: 660.0+ bytes
#
# --- Head (5 rows) ---
#        Column Name                                         Definition
# 0          LOAN_ID                    Unique identifier for the loan.
# 1             DATE  Reporting (snapshot) date on which all loan me...
# 2     CUSTOMER_AGE  Number of days since the loan sale date (SALE_...
# 3       TOTAL_PAID  Cumulative amount paid by the customer up to t...
# 4  TOTAL_DUE_TODAY  Total amount the customer is expected to have ...
# --- Tail (5 rows) ---
#                         Column Name  \
# 28                         DISCOUNT
# ...

# %%
# Profile: NPS_Data
print("\n" + "="*60)
print("DataFrame: NPS_Data")
print("="*60)

# Shape
print(f"\nShape: {NPS_Data.shape[0]:,} rows, {NPS_Data.shape[1]:,} columns")

# Info
print("\n--- Info ---")
NPS_Data.info()

# Head
print("\n--- Head (5 rows) ---")
display(NPS_Data.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(NPS_Data.tail())

# Describe
print("\n--- Describe ---")
display(NPS_Data.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = NPS_Data.isnull().sum()
null_pct = (NPS_Data.isnull().sum() / len(NPS_Data)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = NPS_Data.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: NPS_Data
# ...
#
# Shape: 4,129 rows, 17 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4129 entries, 0 to 4128
# Data columns (total 17 columns):
#  #   Column                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                 --------------  -----
#  0   Submission ID                                                                                                          4129 non-null   object
#  1   Respondent ID                                                                                                          4129 non-null   object
#  2   Submitted at                                                                                                           4129 non-null   datetime64[ns]
# ...

# %%
# Profile: Sales_and_Customer_Data_Sales_Details
print("\n" + "="*60)
print("DataFrame: Sales_and_Customer_Data_Sales_Details")
print("="*60)

# Shape
print(f"\nShape: {Sales_and_Customer_Data_Sales_Details.shape[0]:,} rows, {Sales_and_Customer_Data_Sales_Details.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Sales_and_Customer_Data_Sales_Details.info()

# Head
print("\n--- Head (5 rows) ---")
display(Sales_and_Customer_Data_Sales_Details.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Sales_and_Customer_Data_Sales_Details.tail())

# Describe
print("\n--- Describe ---")
display(Sales_and_Customer_Data_Sales_Details.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Sales_and_Customer_Data_Sales_Details.isnull().sum()
null_pct = (Sales_and_Customer_Data_Sales_Details.isnull().sum() / len(Sales_and_Customer_Data_Sales_Details)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Sales_and_Customer_Data_Sales_Details.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Sales_and_Customer_Data_Sales_Details
# ...
#
# Shape: 1,048,575 rows, 16 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SALE_ID                   20747 non-null  object
#  1   SALE_DATE                 20747 non-null  datetime64[ns]
#  2   RETURNED                  20747 non-null  float64
#  3   RETURN_DATE               1744 non-null   datetime64[ns]
#  4   SALE_TYPE                 20745 non-null  object
#  5   SELLER                    20670 non-null  object
#  6   SELLER_TYPE               15776 non-null  object
#  7   RETURN_POLICY_COMPLIANCE  1744 non-null   object
#  8   CASH_PRICE                20745 non-null  float64
#  9   LOAN_PRICE                20745 non-null  float64
#  10  CLIENT_MODEL              20722 non-null  object
# ...

# %%
# Profile: Sales_and_Customer_Data_Gender
print("\n" + "="*60)
print("DataFrame: Sales_and_Customer_Data_Gender")
print("="*60)

# Shape
print(f"\nShape: {Sales_and_Customer_Data_Gender.shape[0]:,} rows, {Sales_and_Customer_Data_Gender.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Sales_and_Customer_Data_Gender.info()

# Head
print("\n--- Head (5 rows) ---")
display(Sales_and_Customer_Data_Gender.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Sales_and_Customer_Data_Gender.tail())

# Describe
print("\n--- Describe ---")
display(Sales_and_Customer_Data_Gender.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Sales_and_Customer_Data_Gender.isnull().sum()
null_pct = (Sales_and_Customer_Data_Gender.isnull().sum() / len(Sales_and_Customer_Data_Gender)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Sales_and_Customer_Data_Gender.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Sales_and_Customer_Data_Gender
# ...
#
# Shape: 1,048,575 rows, 3 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Loan Id      14896 non-null  object
#  1   Citizenship  49788 non-null  object
#  2   Gender       49783 non-null  object
# dtypes: object(3)
# memory usage: 24.0+ MB
#
# --- Head (5 rows) ---
#   Loan Id Citizenship  Gender
# 0     NaN      KENYAN  Female
# 1     NaN      KENYAN    Male
# 2     NaN      KENYAN    Male
# 3     NaN      KENYAN    Male
# 4     NaN      KENYAN  Female
# --- Tail (5 rows) ---
#         Loan Id Citizenship Gender
# 1048570     NaN         NaN    NaN
# 1048571     NaN         NaN    NaN
# 1048572     NaN         NaN    NaN
# 1048573     NaN         NaN    NaN
# 1048574     NaN         NaN    NaN
# --- Describe ---
# ...

# %%
# Profile: Sales_and_Customer_Data_DOB
print("\n" + "="*60)
print("DataFrame: Sales_and_Customer_Data_DOB")
print("="*60)

# Shape
print(f"\nShape: {Sales_and_Customer_Data_DOB.shape[0]:,} rows, {Sales_and_Customer_Data_DOB.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Sales_and_Customer_Data_DOB.info()

# Head
print("\n--- Head (5 rows) ---")
display(Sales_and_Customer_Data_DOB.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Sales_and_Customer_Data_DOB.tail())

# Describe
print("\n--- Describe ---")
display(Sales_and_Customer_Data_DOB.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Sales_and_Customer_Data_DOB.isnull().sum()
null_pct = (Sales_and_Customer_Data_DOB.isnull().sum() / len(Sales_and_Customer_Data_DOB)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Sales_and_Customer_Data_DOB.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Sales_and_Customer_Data_DOB
# ...
#
# Shape: 1,048,575 rows, 5 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            57130 non-null  object
#  1   provider       57130 non-null  object
#  2   date_of_birth  56921 non-null  object
#  3   Loan Id        13562 non-null  object
#  4   createdAt UTC  57130 non-null  object
# dtypes: object(5)
# memory usage: 40.0+ MB
#
# --- Head (5 rows) ---
#                         _id    provider              date_of_birth  \
# 0  67c57f7b5a877e67ca1e9636  TRANSUNION  1992-01-15T00:00:00+03:00
# 1  67c57f7c5a877e67ca1e964f  TRANSUNION  2002-04-13T00:00:00+03:00
# 2  67c585175a877e67ca1e99eb  TRANSUNION  1991-05-17T00:00:00+03:00
# 3  67c585185a877e67ca1e9a00  TRANSUNION  1969-01-01T00:00:00+03:00
# ...

# %%
# Profile: Sales_and_Customer_Data_Income_Level
print("\n" + "="*60)
print("DataFrame: Sales_and_Customer_Data_Income_Level")
print("="*60)

# Shape
print(f"\nShape: {Sales_and_Customer_Data_Income_Level.shape[0]:,} rows, {Sales_and_Customer_Data_Income_Level.shape[1]:,} columns")

# Info
print("\n--- Info ---")
Sales_and_Customer_Data_Income_Level.info()

# Head
print("\n--- Head (5 rows) ---")
display(Sales_and_Customer_Data_Income_Level.head())

# Tail  
print("\n--- Tail (5 rows) ---")
display(Sales_and_Customer_Data_Income_Level.tail())

# Describe
print("\n--- Describe ---")
display(Sales_and_Customer_Data_Income_Level.describe(include='all'))

# Nulls
print("\n--- Null Values ---")
null_counts = Sales_and_Customer_Data_Income_Level.isnull().sum()
null_pct = (Sales_and_Customer_Data_Income_Level.isnull().sum() / len(Sales_and_Customer_Data_Income_Level)) * 100
null_df = pd.DataFrame({'Count': null_counts, 'Percentage': null_pct})
null_df = null_df[null_df['Count'] > 0].sort_values('Count', ascending=False)
if len(null_df) > 0:
    display(null_df)
else:
    print("No null values found")

# Uniques
print("\n--- Unique Values per Column ---")
unique_counts = Sales_and_Customer_Data_Income_Level.nunique().sort_values()
display(pd.DataFrame({'Unique': unique_counts}))
# Out:
# ...
# DataFrame: Sales_and_Customer_Data_Income_Level
# ...
#
# Shape: 1,048,575 rows, 6 columns
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Loan Id                      11885 non-null  object
#  1   Duration                     22839 non-null  float64
#  2   Received                     22839 non-null  float64
#  3   Persons Received From Total  22839 non-null  float64
#  4   Banks Received               22839 non-null  float64
#  5   Paybills Received Others     22839 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 48.0+ MB
#
# --- Head (5 rows) ---
#   Loan Id  Duration    Received  Persons Received From Total  Banks Received  \
# 0     NaN      12.0   203934.19                     203278.0           100.0
# ...
